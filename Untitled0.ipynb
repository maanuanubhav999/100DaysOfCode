# %% [markdown]
# <a href="https://colab.research.google.com/github/maanuanubhav999/100DaysOfCode/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
import numpy as np

# %%
from tensorflow import keras

# %%
model=tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0905 04:01:52.208372 139940912678784 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %%
model.fit(xs,ys,epochs=500)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 1s 85ms/sample - loss: 109.4004
# Epoch 2/500
# 6/6 [==============================] - 0s 436us/sample - loss: 86.0844
# Epoch 3/500
# 6/6 [==============================] - 0s 479us/sample - loss: 67.7403
# Epoch 4/500
# 6/6 [==============================] - 0s 449us/sample - loss: 53.3077
# Epoch 5/500
# 6/6 [==============================] - 0s 353us/sample - loss: 41.9526
# Epoch 6/500
# 6/6 [==============================] - 0s 274us/sample - loss: 33.0187
# Epoch 7/500
# 6/6 [==============================] - 0s 271us/sample - loss: 25.9896
# Epoch 8/500
# 6/6 [==============================] - 0s 273us/sample - loss: 20.4593
# Epoch 9/500
# 6/6 [==============================] - 0s 273us/sample - loss: 16.1080
# Epoch 10/500
# 6/6 [==============================] - 0s 287us/sample - loss: 12.6844
# Epoch 11/500
# 6/6 [==============================] - 0s 266us/sample - loss: 9.9907
# Epoch 12/500
# ...

# %%
print(model.predicr([30]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-a9d993d41298> in <module>()
# ----> 1 print(model.predicr([30]))
#
# AttributeError: 'Sequential' object has no attribute 'predicr'

# %%
print(model.predict([10.0]))
# Out:
# [[30.995651]]

# %%
print(model.predict([20.25]))
# Out:
# [[61.73919]]
